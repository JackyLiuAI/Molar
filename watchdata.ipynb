# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv("dataset/50k/item_info.csv")
# df = pd.read_csv("dataset/200k/Pixel200K.csv")

# 显示前 5 行
print(df.head())
# Out:
#    item_id  view_number  comment_number  thumbup_number  share_number  \
# 0  i192714     799668.0           739.0          8050.0         220.0
# 1  i225967    1201395.0           102.0         20424.0         738.0
# 2    i8061    2633706.0          2502.0        160379.0       11161.0
# 3  i217203     922049.0           244.0          9878.0         344.0
# 4  i349133     186671.0            50.0          1630.0          67.0
#
#    coin_number  favorite_number  barrage_number  \
# 0         84.0           1049.0           510.0
# 1        502.0           4307.0           510.0
# 2       2439.0          32801.0          1696.0
# 3        228.0           2129.0          1374.0
# 4         87.0           1617.0            76.0
#
#                                                title           tag  \
# 0  My boyfriend gave me a turtle, and it suddenly...  Pet Reptiles
# 1  Who's not a baby anymore! Alaska is being bull...          Dogs
# 2  New York subway rules that pets can't ride the...          Dogs
# 3  The biggest dog in the world. It's so ugly and...          Dogs
# 4  Taylor Swift: Selena and Mould perform Hands T...    Live Music
#
#                                          description
# 0                             Should I brush it off?
# 1  BGM: Don't Leave Me (Ne Me Quitte Pas) - Regin...
# 2                                                 wb
# 3  Super love big dogs, the family has a baby Lab...
# 4                                                NaN

# %%
# 显示总行数
print("\n总行数：", len(df))

# 统计 item_id 和 user_id 的种类数
print("item_id 种类数：", df["item_id"].nunique())
print("user_id 种类数：", df["user_id"].nunique())
