# %%
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv("dataset/50k/item_info.csv")
# df = pd.read_csv("dataset/200k/Pixel200K.csv")
# 打印 item_id 为 i3 对应的信息
print(df[df['item_id'] == 'i3'])
# 单独提取并打印 title 列
print(df[df['item_id'] == 'i3']['title'].to_string(index=False))
print()
# 显示前 5 行
# print(df.head())
# Out:
#       item_id  view_number  comment_number  thumbup_number  share_number  \
# 53411      i3     332826.0           208.0          5674.0         738.0
#
#        coin_number  favorite_number  barrage_number  \
# 53411        783.0           3181.0           643.0
#
#                                                    title          tag  \
# 53411  Erhu Solo Racehorse" at the end makes foreigne...  Performance
#
#       description
# 53411         NaN
# Erhu Solo Racehorse" at the end makes foreigner...

# %%
# 显示总行数
print("\n总行数：", len(df))

# 统计 item_id 和 user_id 的种类数
print("item_id 种类数：", df["item_id"].nunique())
print("user_id 种类数：", df["user_id"].nunique())
